# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files

uploaded = files.upload()
data_read = pd.read_excel('shooping_demo.xls')
data_read.head()
# Out:
#      <input type="file" id="files-a98827ce-b099-4510-bdac-4d29d32d859a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a98827ce-b099-4510-bdac-4d29d32d859a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data_read.shape
# Out:
# (50, 4)

# %%
data_read['Buy'].value_counts()
# Out:
# Buy
# Yes    41
# No      9
# Name: count, dtype: int64

# %%
pYes = 24/30
pNo = 6/30

# %%
print(pYes)
# Out:
# 0.8

# %%
print(pNo)
# Out:
# 0.2

# %%
pd.crosstab(data_read['Day'], data_read['Buy'])
# Out:
# Buy      No  Yes
# Day
# Holiday   6   18
# Weekday   2    9
# Weekend   1   14

# %%
BHolidayNo = 6/6
BWeekdayNo = 2/6
BWeekendNo = 1/6

BHolidayYes = 18/24
BWeekdayYes = 9/24
BWeekendYes = 14/24

BHoliday = 24/30
BWeekday = 11/30
BWeekend = 15/30

print(BWeekdayYes)
# Out:
# 0.375

# %%
# P(A|B) ?
# P(B) = BWeekday
# P (A) = No Buy
# p(B|A) = P Weekend/No Buy

# %%
pNoWeekday = (BWeekdayNo*pNo)/BWeekday
print(pNoWeekday)
# Out:
# 0.18181818181818182

# %%
pYesweekday = (BWeekdayYes*pYes)/BWeekday
print(pYesweekday)
# Out:
# 0.8181818181818183

# %%
# probabilitas (Buy| Weekday) > dibanding dengan probabilitas (NoBuy | Weekday)
print(pNoWeekday)
print(pYesweekday)
# Out:
# 0.18181818181818182
# 0.8181818181818183

# %%
# kondisi B dimana
# day = Holiday
# Discount = Yes
# Free Delivery = Yes
# A =NoBuy
# P(A|B) = P(NoBuy|discountYes, Free Delivery Yes, PDayHoliday)

# %%
pd.crosstab(data_read['Discount'], data_read['Buy'])
# Out:
# Buy       No  Yes
# Discount
# No         5   12
# Yes        4   29

# %%
pNoDiscountNo = 5/6
pYesDiscountNo = 4/6

pNoDiscountYes = 12/24
pYesDiscountYes = 29/24

pNoDiscount = 17/30
pYesdiscount = 33/30

# %%
pd.crosstab(data_read['Free Delivery'], data_read['Buy'])
# Out:
# Buy            No  Yes
# Free Delivery
# No              4   10
# Yes             5   31

# %%
pNoDeliveryNo= 4/6
pYesDeliveryNo= 5/6

pNoDeliveryYes = 10/24
pYesDeliveryYes = 31/24

pNodelivery = 14/30
pYesDelivery = 36/30

# %%
#Kondisi B dimana

# Day Holiday

#Discount = Yes

#Free Delivery = Yes
#P(A) NoBuy = PNo
#P(B) pYesDiscount, pYes Delivery, BHoliday
#P(B/A)1 (BHoliday No Buy) BHoliday No
#P(B/A)2 = (pYesDiscount No Buy) = pYesDiscountNo
#P(B/A)3 = (pYesDelivery No Buy) = pYesDeliveryNo
#P(B)1 BHoliday
#P(B)2 pYesDiscount
#P(B)3 pYesDelivery
#ditanyakan P(A/B) ?
#Rumus
#P(A/B) = P(B|A)*P(A)/P(B)

# %%
pNoBuy1 = ((BHolidayNo*pYesDiscountNo*pYesDeliveryNo)*pNo)/(BHoliday*pYesdiscount*pYesDelivery)
print(pNoBuy1)
# Out:
# 0.10521885521885523

# %%
#Kondisi B dimana
#Day Holiday
#Discount = Yes
#Free Delivery = Yes
#P(A) Buy = pYes
#P(B) pYes Discount, pYes Delivery, BHoliday
#P(B|A)1 (BHoliday Buy) = BHolidayYes
#P(B/A)2 (pYesDiscount Buy) pYesDiscountYes
#P(B|A)3 = (pYesDelivery Buy) = pYesDeliveryYes I
#P(B)1 BHoliday
#P(B)2 pYesDiscount
#P(B)3 pYesDelivery

#ditanyakan P(A/B) ?
#Rumus
#P(A/B) = P(B|A)*P(A)/P(B)

# %%
pBuy2 = ((BHolidayYes*pYesDiscountYes*pYesDeliveryYes)*pYes)/(BHoliday*pYesdiscount*pYesDelivery)
print (pBuy2)
# Out:
# 0.8867976641414141

# %%
# probablity of no buy = 0.10521885521885523
# probablity of buy = 0.8867976641414141

# %%
pSum = pNoBuy1+pBuy2
print(pSum)
# Out:
# 0.9920165193602694

# %%
pBuy = pBuy2/pSum *100
print(pBuy)
# Out:
# 89.39343718926087

# %%
pNoBuy = (pNoBuy1*pSum) *100
print(pNoBuy)
# Out:
# 10.437884252528088
